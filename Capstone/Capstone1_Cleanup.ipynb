# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
#import fight data csv as a DF
fight_data = pd.read_csv('data_folder/raw_total_fight_data.csv', sep = ';', header = 0)

# %%
#inspect the new DF
fight_data.head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR. B_SIG_STR.  \
# 0          Henry Cejudo   Marlon Moraes     0     0   90 of 171  57 of 119
# 1  Valentina Shevchenko     Jessica Eye     1     0     8 of 11    2 of 12
# 2         Tony Ferguson  Donald Cerrone     0     0  104 of 200  68 of 185
# 3         Jimmie Rivera        Petr Yan     0     2   73 of 192  56 of 189
# 4           Tai Tuivasa   Blagoy Ivanov     0     1   64 of 144  73 of 123
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.    R_TD    B_TD  \
# 0           52%           47%    99 of 182    59 of 121  1 of 4  0 of 2
# 1           72%           16%     37 of 40     42 of 52  2 of 2  0 of 0
# 2           52%           36%   104 of 200    68 of 185  0 of 0  1 of 1
# 3           38%           29%    76 of 195    58 of 192  0 of 3  1 of 3
# 4           44%           59%    66 of 146    81 of 131  0 of 0  2 of 2
#
#   R_TD_pct B_TD_pct  R_SUB_ATT  B_SUB_ATT  R_PASS  B_PASS  R_REV  B_REV  \
# ...

# %%
#further DF inspection
fight_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5144 entries, 0 to 5143
# Data columns (total 41 columns):
# R_fighter          5144 non-null object
# B_fighter          5144 non-null object
# R_KD               5144 non-null int64
# B_KD               5144 non-null int64
# R_SIG_STR.         5144 non-null object
# B_SIG_STR.         5144 non-null object
# R_SIG_STR_pct      5144 non-null object
# B_SIG_STR_pct      5144 non-null object
# R_TOTAL_STR.       5144 non-null object
# B_TOTAL_STR.       5144 non-null object
# R_TD               5144 non-null object
# B_TD               5144 non-null object
# R_TD_pct           5144 non-null object
# B_TD_pct           5144 non-null object
# R_SUB_ATT          5144 non-null int64
# B_SUB_ATT          5144 non-null int64
# R_PASS             5144 non-null int64
# B_PASS             5144 non-null int64
# R_REV              5144 non-null int64
# B_REV              5144 non-null int64
# R_HEAD             5144 non-null object
# ...

# %%
#See how much data is missing in DF
fight_data.isna().sum()
# Out:
# R_fighter           0
# B_fighter           0
# R_KD                0
# B_KD                0
# R_SIG_STR.          0
# B_SIG_STR.          0
# R_SIG_STR_pct       0
# B_SIG_STR_pct       0
# R_TOTAL_STR.        0
# B_TOTAL_STR.        0
# R_TD                0
# B_TD                0
# R_TD_pct            0
# B_TD_pct            0
# R_SUB_ATT           0
# B_SUB_ATT           0
# R_PASS              0
# B_PASS              0
# R_REV               0
# B_REV               0
# R_HEAD              0
# B_HEAD              0
# R_BODY              0
# B_BODY              0
# R_LEG               0
# B_LEG               0
# R_DISTANCE          0
# B_DISTANCE          0
# R_CLINCH            0
# B_CLINCH            0
# R_GROUND            0
# B_GROUND            0
# win_by              0
# last_round          0
# last_round_time     0
# Format              0
# Referee            23
# date                0
# location            0
# Fight_type          0
# Winner             83
# dtype: int64

# %%
#See what is missing in the DF
empty_winner = fight_data.loc[fight_data['Winner'].isnull(), :]

# %%
empty_winner
# Out:
#                   R_fighter            B_fighter  R_KD  B_KD  R_SIG_STR.  \
# 228         Andrei Arlovski          Walt Harris     0     0    44 of 93
# 331            Matt Frevola        Lando Vannata     0     2   66 of 176
# 363            Randa Markos     Marina Rodriguez     0     0   48 of 116
# 702     Khalil Rountree Jr.  Michal Oleksiejczuk     0     0   52 of 180
# 704          Marvin Vettori       Omari Akhmedov     0     0   66 of 161
# 748          DeAnna Bennett       Melinda Fabian     0     1    47 of 81
# 831          Beneil Dariush          Evan Dunham     1     0   81 of 157
# 833           Lando Vannata          Bobby Green     1     0  104 of 232
# 893          Daniel Cormier            Jon Jones     0     1   58 of 140
# 1011          Eddie Alvarez       Dustin Poirier     0     0   44 of 127
# 1068          Vitor Belfort      Kelvin Gastelum     0     2    10 of 28
# 1072          Bethe Correia        Marion Reneau     0     0    43 of 95
# ...

# %%
#Load in the fighter details CSV as a DF
fighter_details = pd.read_csv('data_folder/raw_fighter_details.csv', header=0)

# %%
fighter_details.head()
# Out:
#   fighter_name  Height    Weight Reach Stance  DOB
# 0   AJ Fonseca   5' 4"  145 lbs.   NaN    NaN  NaN
# 1  AJ Matthews  5' 11"  185 lbs.   NaN    NaN  NaN
# 2     AJ McKee  5' 10"  145 lbs.   NaN    NaN  NaN
# 3    AJ Siscoe   5' 7"  135 lbs.   NaN    NaN  NaN
# 4   Aalon Cruz   6' 0"  145 lbs.   NaN    NaN  NaN

# %%
#inspect the new DF
#Loks like we're missing a lot of information about reach, stance, and DOB
#^Above is in order of increasing amounts of missing data
fighter_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3313 entries, 0 to 3312
# Data columns (total 6 columns):
# fighter_name    3313 non-null object
# Height          3050 non-null object
# Weight          3238 non-null object
# Reach           1569 non-null object
# Stance          2439 non-null object
# DOB             2573 non-null object
# dtypes: object(6)
# memory usage: 155.4+ KB

# %%
#Now I want to map the stats from the 'fighter_details' DF to the 'fight_data' DF where there 
#will be new columns created based on whether it is R fighter details or B fighter details
#I want all of the columns from 'fighter_details' to be added on

part_data = pd.merge(fight_data, fighter_details, how = 'left', left_on = 'R_fighter', right_on = 'fighter_name')

# %%
part_data.head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR. B_SIG_STR.  \
# 0          Henry Cejudo   Marlon Moraes     0     0   90 of 171  57 of 119
# 1  Valentina Shevchenko     Jessica Eye     1     0     8 of 11    2 of 12
# 2         Tony Ferguson  Donald Cerrone     0     0  104 of 200  68 of 185
# 3         Jimmie Rivera        Petr Yan     0     2   73 of 192  56 of 189
# 4           Tai Tuivasa   Blagoy Ivanov     0     1   64 of 144  73 of 123
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.    R_TD    B_TD  \
# 0           52%           47%    99 of 182    59 of 121  1 of 4  0 of 2
# 1           72%           16%     37 of 40     42 of 52  2 of 2  0 of 0
# 2           52%           36%   104 of 200    68 of 185  0 of 0  1 of 1
# 3           38%           29%    76 of 195    58 of 192  0 of 3  1 of 3
# 4           44%           59%    66 of 146    81 of 131  0 of 0  2 of 2
#
#   R_TD_pct B_TD_pct  R_SUB_ATT  B_SUB_ATT  R_PASS  B_PASS  R_REV  B_REV  \
# ...

# %%
part_data.rename(columns = {'fighter_name':'Red_fighter','Height':'R_Height', 'Weight':'R_Weight', 'Reach':'R_Reach', 'Stance':'R_Stance', 'DOB':'R_DOB'}, inplace=True)

# %%
part_data.head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR. B_SIG_STR.  \
# 0          Henry Cejudo   Marlon Moraes     0     0   90 of 171  57 of 119
# 1  Valentina Shevchenko     Jessica Eye     1     0     8 of 11    2 of 12
# 2         Tony Ferguson  Donald Cerrone     0     0  104 of 200  68 of 185
# 3         Jimmie Rivera        Petr Yan     0     2   73 of 192  56 of 189
# 4           Tai Tuivasa   Blagoy Ivanov     0     1   64 of 144  73 of 123
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.    R_TD    B_TD  \
# 0           52%           47%    99 of 182    59 of 121  1 of 4  0 of 2
# 1           72%           16%     37 of 40     42 of 52  2 of 2  0 of 0
# 2           52%           36%   104 of 200    68 of 185  0 of 0  1 of 1
# 3           38%           29%    76 of 195    58 of 192  0 of 3  1 of 3
# 4           44%           59%    66 of 146    81 of 131  0 of 0  2 of 2
#
#   R_TD_pct B_TD_pct  R_SUB_ATT  B_SUB_ATT  R_PASS  B_PASS  R_REV  B_REV  \
# ...

# %%
#Merge in Blue fighter data
all_data = pd.merge(part_data, fighter_details, how = 'left', left_on = 'B_fighter', right_on = 'fighter_name')

# %%
#inspect this
all_data.head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR. B_SIG_STR.  \
# 0          Henry Cejudo   Marlon Moraes     0     0   90 of 171  57 of 119
# 1  Valentina Shevchenko     Jessica Eye     1     0     8 of 11    2 of 12
# 2         Tony Ferguson  Donald Cerrone     0     0  104 of 200  68 of 185
# 3         Jimmie Rivera        Petr Yan     0     2   73 of 192  56 of 189
# 4           Tai Tuivasa   Blagoy Ivanov     0     1   64 of 144  73 of 123
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.    R_TD    B_TD  \
# 0           52%           47%    99 of 182    59 of 121  1 of 4  0 of 2
# 1           72%           16%     37 of 40     42 of 52  2 of 2  0 of 0
# 2           52%           36%   104 of 200    68 of 185  0 of 0  1 of 1
# 3           38%           29%    76 of 195    58 of 192  0 of 3  1 of 3
# 4           44%           59%    66 of 146    81 of 131  0 of 0  2 of 2
#
#   R_TD_pct B_TD_pct  R_SUB_ATT  B_SUB_ATT  R_PASS  B_PASS  R_REV  B_REV  \
# ...

# %%
#rename Blue fighter columns for consistency
all_data.rename(columns = {'fighter_name':'Blue_fighter','Height':'B_Height', 'Weight':'B_Weight', 'Reach':'B_Reach', 'Stance':'B_Stance', 'DOB':'B_DOB'}, inplace=True)

# %%
all_data.head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR. B_SIG_STR.  \
# 0          Henry Cejudo   Marlon Moraes     0     0   90 of 171  57 of 119
# 1  Valentina Shevchenko     Jessica Eye     1     0     8 of 11    2 of 12
# 2         Tony Ferguson  Donald Cerrone     0     0  104 of 200  68 of 185
# 3         Jimmie Rivera        Petr Yan     0     2   73 of 192  56 of 189
# 4           Tai Tuivasa   Blagoy Ivanov     0     1   64 of 144  73 of 123
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.    R_TD    B_TD  \
# 0           52%           47%    99 of 182    59 of 121  1 of 4  0 of 2
# 1           72%           16%     37 of 40     42 of 52  2 of 2  0 of 0
# 2           52%           36%   104 of 200    68 of 185  0 of 0  1 of 1
# 3           38%           29%    76 of 195    58 of 192  0 of 3  1 of 3
# 4           44%           59%    66 of 146    81 of 131  0 of 0  2 of 2
#
#   R_TD_pct B_TD_pct  R_SUB_ATT  B_SUB_ATT  R_PASS  B_PASS  R_REV  B_REV  \
# ...

# %%
#Convert date column to datetime
all_data['date'] = all_data['date'].astype('datetime64[ns]')

# %%
#verify that above conversion occurred
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5144 entries, 0 to 5143
# Data columns (total 53 columns):
# R_fighter          5144 non-null object
# B_fighter          5144 non-null object
# R_KD               5144 non-null int64
# B_KD               5144 non-null int64
# R_SIG_STR.         5144 non-null object
# B_SIG_STR.         5144 non-null object
# R_SIG_STR_pct      5144 non-null object
# B_SIG_STR_pct      5144 non-null object
# R_TOTAL_STR.       5144 non-null object
# B_TOTAL_STR.       5144 non-null object
# R_TD               5144 non-null object
# B_TD               5144 non-null object
# R_TD_pct           5144 non-null object
# B_TD_pct           5144 non-null object
# R_SUB_ATT          5144 non-null int64
# B_SUB_ATT          5144 non-null int64
# R_PASS             5144 non-null int64
# B_PASS             5144 non-null int64
# R_REV              5144 non-null int64
# B_REV              5144 non-null int64
# R_HEAD             5144 non-null object
# ...

# %%
#Next steps would be change "Winner" perspective to "R_Won?" to get perspective of what happens to the Red
#fighter when the model is ready.

#After above, want to do rolling cum mean or rolling average to get each row to be average
#fighter details up until that point.

# %%
#Did R_fighter win? 
all_data['R_won'] = all_data['R_fighter']==all_data['Winner']

# %%
#Testing if it worked
all_data['R_won'].head()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: R_won, dtype: bool

# %%
all_data.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR.', 'B_SIG_STR.',
#        'R_SIG_STR_pct', 'B_SIG_STR_pct', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
#        'R_TD', 'B_TD', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_PASS', 'B_PASS', 'R_REV', 'B_REV', 'R_HEAD', 'B_HEAD', 'R_BODY',
#        'B_BODY', 'R_LEG', 'B_LEG', 'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH',
#        'B_CLINCH', 'R_GROUND', 'B_GROUND', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'location',
#        'Fight_type', 'Winner', 'Red_fighter', 'R_Height', 'R_Weight',
#        'R_Reach', 'R_Stance', 'R_DOB', 'Blue_fighter', 'B_Height', 'B_Weight',
#        'B_Reach', 'B_Stance', 'B_DOB', 'R_won'],
#       dtype='object')

# %%
#df.groupby('id')['x'].apply(pd.rolling_mean, 2, min_periods=1)
grouped_data = all_data.groupby(['R_fighter'])

# %%
grouped_data.head(30)
# Out:
#                   R_fighter            B_fighter  R_KD  B_KD  R_SIG_STR.  \
# 0              Henry Cejudo        Marlon Moraes     0     0   90 of 171
# 1      Valentina Shevchenko          Jessica Eye     1     0     8 of 11
# 2             Tony Ferguson       Donald Cerrone     0     0  104 of 200
# 3             Jimmie Rivera             Petr Yan     0     2   73 of 192
# 4               Tai Tuivasa        Blagoy Ivanov     0     1   64 of 144
# 5            Tatiana Suarez        Nina Ansaroff     0     0   75 of 142
# 6         Aljamain Sterling         Pedro Munhoz     0     0  174 of 349
# 7     Karolina Kowalkiewicz         Alexa Grasso     0     0   90 of 232
# 8             Ricardo Lamas        Calvin Kattar     0     1    12 of 29
# 9               Yan Xiaonan          Angela Hill     0     0   94 of 249
# 10              Bevon Lewis       Darren Stewart     0     0    31 of 84
# 11           Eddie Wineland       Grigorii Popov     2     0   74 of 171
# ...

# %%
#Get number of unique values for certain columns like: "win_by", "last_round", "Fight_type"
#From here can expand and add in more columns for each unique value from the above

all_data.nunique()
# Out:
# R_fighter          1334
# B_fighter          1774
# R_KD                  6
# B_KD                  5
# R_SIG_STR.         3038
# B_SIG_STR.         2903
# R_SIG_STR_pct        95
# B_SIG_STR_pct        90
# R_TOTAL_STR.       3681
# B_TOTAL_STR.       3479
# R_TD                157
# B_TD                154
# R_TD_pct             69
# B_TD_pct             62
# R_SUB_ATT            11
# B_SUB_ATT             8
# R_PASS               21
# B_PASS               15
# R_REV                 6
# B_REV                 4
# R_HEAD             2620
# B_HEAD             2475
# R_BODY              541
# B_BODY              508
# R_LEG               393
# B_LEG               355
# R_DISTANCE         2382
# B_DISTANCE         2391
# R_CLINCH            472
# B_CLINCH            469
# R_GROUND            641
# B_GROUND            465
# win_by               10
# last_round            5
# last_round_time     333
# Format               19
# Referee             190
# date                476
# ...

# %%
#Got list of fighter names and got rid of dupes
fighter_names = set((all_data['R_fighter']))

# %%
print(fighter_names)
# Out:
# {'Aspen Ladd', 'Falaniko Vitale', 'Kyoji Horiguchi', 'Yui Chul Nam', 'Pedro Munhoz', 'Erick Silva', 'Mike Brown', 'Dong Hyun Ma', 'Niklas Backstrom', 'Emily Peters Kagan', 'Colby Covington', 'Suman Mokhtarian', 'Yves Jabouin', 'Jake Ellenberger', 'Luana Carolina', 'Matt Brown', 'Ryo Chonan', 'Ariel Beck', 'Joseph Sandoval', 'Mark Kerr', 'Josh Samman', 'Megan Anderson', 'Chris Tuchscherer', 'Ramazan Emeev', 'Daniel Teymur', 'Jesse Forbes', 'Yoshiyuki Yoshida', 'Aaron Phillips', 'Nate Diaz', 'Max Holloway', 'Alexis Dufresne', 'Frankie Edgar', 'Kendall Grove', 'Masio Fullen', 'Steven Peterson', 'Nad Narimani', 'Zabit Magomedsharipov', "Sean O'Malley", 'Cole Escovedo', 'Kris McCray', 'Mads Burnell', 'Krzysztof Jotko', 'Heath Herring', 'Alexander Volkanovski', 'Montel Jackson', 'Augusto Montano', 'Cris Cyborg', 'Russell Doane', 'Joe Doerksen', 'Jake Matthews', 'Salim Touahri', 'Keith Rockel', 'Alessio Di Chirico', 'Jesse Ronson', 'Ronny Markes', 'Joseph Benavidez', 'Marion Reneau', 'Lee M
# ...

# %%
all_data.loc[all_data['R_fighter'] == 'Greg Hardy']
# Out:
#       R_fighter          B_fighter  R_KD  B_KD R_SIG_STR. B_SIG_STR.  \
# 63   Greg Hardy  Dmitrii Smoliakov     0     0   14 of 30     1 of 3
# 211  Greg Hardy      Allen Crowder     0     0   29 of 64   12 of 30
#
#     R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.    R_TD    B_TD  \
# 63            46%           33%     17 of 33       1 of 3  0 of 0  0 of 2
# 211           45%           40%     35 of 70     16 of 34  0 of 0  1 of 3
#
#     R_TD_pct B_TD_pct  R_SUB_ATT  B_SUB_ATT  R_PASS  B_PASS  R_REV  B_REV  \
# 63        0%       0%          0          0       0       0      0      0
# 211       0%      33%          0          1       0       2      0      0
#
#        R_HEAD    B_HEAD  R_BODY  B_BODY   R_LEG   B_LEG R_DISTANCE B_DISTANCE  \
# 63   12 of 28    1 of 3  2 of 2  0 of 0  0 of 0  0 of 0    4 of 13     1 of 3
# 211  21 of 56  12 of 30  5 of 5  0 of 0  3 of 3  0 of 0   17 of 51    8 of 25
#
# ...

# %% [markdown]
# Seperate the blue and red so you have each fighter's stats on a given date.
# From there, should be 1 fighter_name column that you can use to get their averages on a given date and can predict historical and future of who wins. Would import this new DF to old DF later.

# %%
#Creating a new DF that only has blue fighter data
#Then create a new DF with only red fighter data
#Then stich them together - top and bottom
#blue = pd.DataFrame(
    #[p] for p in all_data
#)
blue = []
for p in all_data:
    if 'B_' in p:
        blue.append(p)

# %%
print(blue)
# Out:
# ['B_fighter', 'B_KD', 'B_SIG_STR.', 'B_SIG_STR_pct', 'B_TOTAL_STR.', 'B_TD', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT', 'B_PASS', 'B_REV', 'B_HEAD', 'B_BODY', 'B_LEG', 'B_DISTANCE', 'B_CLINCH', 'B_GROUND', 'B_Height', 'B_Weight', 'B_Reach', 'B_Stance', 'B_DOB']

# %%
blue.index('R_SUB_ATT')
# Out:
# 7

# %%
del(blue[7])

# %%
blue.append('date')

# %%
print(blue)
# Out:
# ['B_fighter', 'B_KD', 'B_SIG_STR.', 'B_SIG_STR_pct', 'B_TOTAL_STR.', 'B_TD', 'B_TD_pct', 'B_SUB_ATT', 'B_PASS', 'B_REV', 'B_HEAD', 'B_BODY', 'B_LEG', 'B_DISTANCE', 'B_CLINCH', 'B_GROUND', 'B_Height', 'B_Weight', 'B_Reach', 'B_Stance', 'B_DOB', 'date']

# %%
blue_df = all_data[blue]

# %%
blue_df.head()
# Out:
#         B_fighter  B_KD B_SIG_STR. B_SIG_STR_pct B_TOTAL_STR.    B_TD  \
# 0   Marlon Moraes     0  57 of 119           47%    59 of 121  0 of 2
# 1     Jessica Eye     0    2 of 12           16%     42 of 52  0 of 0
# 2  Donald Cerrone     0  68 of 185           36%    68 of 185  1 of 1
# 3        Petr Yan     2  56 of 189           29%    58 of 192  1 of 3
# 4   Blagoy Ivanov     1  73 of 123           59%    81 of 131  2 of 2
#
#   B_TD_pct  B_SUB_ATT  B_PASS  B_REV     B_HEAD    B_BODY     B_LEG  \
# 0       0%          0       0      0   35 of 89    7 of 8  15 of 22
# 1       0%          0       0      0     0 of 7    0 of 2    2 of 3
# 2     100%          0       0      0  43 of 152  15 of 23  10 of 10
# 3      33%          0       1      0  40 of 166  13 of 19    3 of 4
# 4     100%          0       0      0  65 of 114    7 of 8    1 of 1
#
#   B_DISTANCE  B_CLINCH B_GROUND B_Height  B_Weight B_Reach  B_Stance  \
# ...

# %%
blue_df.columns = ['fighter_name','knock_down', 'sig_strikes', 'sig_strike_pct','total_strikes','takedown', 'takdown_pct','submission_att','pass','rev','head','body','leg','distance','clinch','ground','height','weight','reach','stance','DOB','date']

# %%
blue_df.head()
# Out:
#      fighter_name  knock_down sig_strikes sig_strike_pct total_strikes  \
# 0   Marlon Moraes           0   57 of 119            47%     59 of 121
# 1     Jessica Eye           0     2 of 12            16%      42 of 52
# 2  Donald Cerrone           0   68 of 185            36%     68 of 185
# 3        Petr Yan           2   56 of 189            29%     58 of 192
# 4   Blagoy Ivanov           1   73 of 123            59%     81 of 131
#
#   takedown takdown_pct  submission_att  pass  rev       head      body  \
# 0   0 of 2          0%               0     0    0   35 of 89    7 of 8
# 1   0 of 0          0%               0     0    0     0 of 7    0 of 2
# 2   1 of 1        100%               0     0    0  43 of 152  15 of 23
# 3   1 of 3         33%               0     1    0  40 of 166  13 of 19
# 4   2 of 2        100%               0     0    0  65 of 114    7 of 8
#
#         leg   distance    clinch   ground  height    weight reach    stance  \
# ...

# %%
red = []
for p in all_data:
    if 'R_' in p:
        red.append(p)

# %%
[p for p in all_data if 'R_' in p]
# Out:
# ['R_fighter',
#  'R_KD',
#  'R_SIG_STR.',
#  'R_SIG_STR_pct',
#  'B_SIG_STR_pct',
#  'R_TOTAL_STR.',
#  'R_TD',
#  'R_TD_pct',
#  'R_SUB_ATT',
#  'R_PASS',
#  'R_REV',
#  'R_HEAD',
#  'R_BODY',
#  'R_LEG',
#  'R_DISTANCE',
#  'R_CLINCH',
#  'R_GROUND',
#  'R_Height',
#  'R_Weight',
#  'R_Reach',
#  'R_Stance',
#  'R_DOB',
#  'R_won']

# %%
red_df = all_data.loc[:,all_data.columns.str.startswith('R_')]

# %%
red_df.head()
# Out:
#               R_fighter  R_KD  R_SIG_STR. R_SIG_STR_pct R_TOTAL_STR.    R_TD  \
# 0          Henry Cejudo     0   90 of 171           52%    99 of 182  1 of 4
# 1  Valentina Shevchenko     1     8 of 11           72%     37 of 40  2 of 2
# 2         Tony Ferguson     0  104 of 200           52%   104 of 200  0 of 0
# 3         Jimmie Rivera     0   73 of 192           38%    76 of 195  0 of 3
# 4           Tai Tuivasa     0   64 of 144           44%    66 of 146  0 of 0
#
#   R_TD_pct  R_SUB_ATT  R_PASS  R_REV     R_HEAD    R_BODY     R_LEG  \
# 0      25%          1       1      0  73 of 150  13 of 16    4 of 5
# 1     100%          1       3      0     4 of 5    4 of 6    0 of 0
# 2       0%          0       0      0  65 of 144  25 of 37  14 of 19
# 3       0%          0       0      0  42 of 145  15 of 24  16 of 23
# 4       0%          0       0      0  39 of 114    6 of 7  19 of 23
#
#    R_DISTANCE  R_CLINCH  R_GROUND R_Height  R_Weight R_Reach  R_Stance  \
# ...

# %%
print(red)
# Out:
# ['R_fighter', 'R_KD', 'R_SIG_STR.', 'R_SIG_STR_pct', 'B_SIG_STR_pct', 'R_TOTAL_STR.', 'R_TD', 'R_TD_pct', 'R_SUB_ATT', 'R_PASS', 'R_REV', 'R_HEAD', 'R_BODY', 'R_LEG', 'R_DISTANCE', 'R_CLINCH', 'R_GROUND', 'R_Height', 'R_Weight', 'R_Reach', 'R_Stance', 'R_DOB', 'R_won']

# %%
red.index('B_SIG_STR_pct')
# Out:
# 4

# %%
del(red[4])

# %%
print(red)
# Out:
# ['R_fighter', 'R_KD', 'R_SIG_STR.', 'R_SIG_STR_pct', 'R_TOTAL_STR.', 'R_TD', 'R_TD_pct', 'R_SUB_ATT', 'R_PASS', 'R_REV', 'R_HEAD', 'R_BODY', 'R_LEG', 'R_DISTANCE', 'R_CLINCH', 'R_GROUND', 'R_Height', 'R_Weight', 'R_Reach', 'R_Stance', 'R_DOB', 'R_won']

# %%
red.index('R_won')
# Out:
# 21

# %%
del(red[21])

# %%
print(red)
# Out:
# ['R_fighter', 'R_KD', 'R_SIG_STR.', 'R_SIG_STR_pct', 'R_TOTAL_STR.', 'R_TD', 'R_TD_pct', 'R_SUB_ATT', 'R_PASS', 'R_REV', 'R_HEAD', 'R_BODY', 'R_LEG', 'R_DISTANCE', 'R_CLINCH', 'R_GROUND', 'R_Height', 'R_Weight', 'R_Reach', 'R_Stance', 'R_DOB']

# %%
red.append('date')

# %%
print(red)
# Out:
# ['R_fighter', 'R_KD', 'R_SIG_STR.', 'R_SIG_STR_pct', 'R_TOTAL_STR.', 'R_TD', 'R_TD_pct', 'R_SUB_ATT', 'R_PASS', 'R_REV', 'R_HEAD', 'R_BODY', 'R_LEG', 'R_DISTANCE', 'R_CLINCH', 'R_GROUND', 'R_Height', 'R_Weight', 'R_Reach', 'R_Stance', 'R_DOB', 'date']

# %%
red_df = all_data[red]

# %%
red_df.head()
# Out:
#               R_fighter  R_KD  R_SIG_STR. R_SIG_STR_pct R_TOTAL_STR.    R_TD  \
# 0          Henry Cejudo     0   90 of 171           52%    99 of 182  1 of 4
# 1  Valentina Shevchenko     1     8 of 11           72%     37 of 40  2 of 2
# 2         Tony Ferguson     0  104 of 200           52%   104 of 200  0 of 0
# 3         Jimmie Rivera     0   73 of 192           38%    76 of 195  0 of 3
# 4           Tai Tuivasa     0   64 of 144           44%    66 of 146  0 of 0
#
#   R_TD_pct  R_SUB_ATT  R_PASS  R_REV     R_HEAD    R_BODY     R_LEG  \
# 0      25%          1       1      0  73 of 150  13 of 16    4 of 5
# 1     100%          1       3      0     4 of 5    4 of 6    0 of 0
# 2       0%          0       0      0  65 of 144  25 of 37  14 of 19
# 3       0%          0       0      0  42 of 145  15 of 24  16 of 23
# 4       0%          0       0      0  39 of 114    6 of 7  19 of 23
#
#    R_DISTANCE  R_CLINCH  R_GROUND R_Height  R_Weight R_Reach  R_Stance  \
# ...

# %%
red_df.columns = ['fighter_name','knock_down', 'sig_strikes', 'sig_strike_pct','total_strikes','takedown', 'takdown_pct','submission_att','pass','rev','head','body','leg','distance','clinch','ground','height','weight','reach','stance','DOB','date']

# %%
red_df.head()
# Out:
#            fighter_name  knock_down sig_strikes sig_strike_pct total_strikes  \
# 0          Henry Cejudo           0   90 of 171            52%     99 of 182
# 1  Valentina Shevchenko           1     8 of 11            72%      37 of 40
# 2         Tony Ferguson           0  104 of 200            52%    104 of 200
# 3         Jimmie Rivera           0   73 of 192            38%     76 of 195
# 4           Tai Tuivasa           0   64 of 144            44%     66 of 146
#
#   takedown takdown_pct  submission_att  pass  rev       head      body  \
# 0   1 of 4         25%               1     1    0  73 of 150  13 of 16
# 1   2 of 2        100%               1     3    0     4 of 5    4 of 6
# 2   0 of 0          0%               0     0    0  65 of 144  25 of 37
# 3   0 of 3          0%               0     0    0  42 of 145  15 of 24
# 4   0 of 0          0%               0     0    0  39 of 114    6 of 7
#
# ...

# %% [markdown]
# Now that DFs have been separated, going to stitch them together, do a group by for fighter name, then do a rolling mean of last 5 fights

# %%
stacked_data = pd.concat([red_df, blue_df], axis=0)

# %%
stacked_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10288 entries, 0 to 5143
# Data columns (total 22 columns):
# fighter_name      10288 non-null object
# knock_down        10288 non-null int64
# sig_strikes       10288 non-null object
# sig_strike_pct    10288 non-null object
# total_strikes     10288 non-null object
# takedown          10288 non-null object
# takdown_pct       10288 non-null object
# submission_att    10288 non-null int64
# pass              10288 non-null int64
# rev               10288 non-null int64
# head              10288 non-null object
# body              10288 non-null object
# leg               10288 non-null object
# distance          10288 non-null object
# clinch            10288 non-null object
# ground            10288 non-null object
# height            10276 non-null object
# weight            10279 non-null object
# reach             9306 non-null object
# stance            9995 non-null object
# DOB               10052 non-null object
# ...

# %%
stacked_data.reset_index(drop=True, inplace = True)

# %%
#Trying to remove the % so I can turn certain columns to floats
def rm_pct(x):
    return float(x.strip('%'))/100

# %%
stacked_data['takdown_pct'] = stacked_data['takdown_pct'].apply(rm_pct)
stacked_data['sig_strike_pct'] = stacked_data['sig_strike_pct'].apply(rm_pct)

# %%
stacked_data['takdown_pct'].head()
# Out:
# 0    0.25
# 1    1.00
# 2    0.00
# 3    0.00
# 4    0.00
# Name: takdown_pct, dtype: float64

# %%
stacked_data['sig_strike_pct'].head()
# Out:
# 0    0.52
# 1    0.72
# 2    0.52
# 3    0.38
# 4    0.44
# Name: sig_strike_pct, dtype: float64

# %%
def test(x):
    print(x)
    print(type(x))
    print('     ')
    x.takdown_pct = float(x.takdown_pct.strip('%'))/100
    return x

# %%
stacked_data[['takdown_pct','sig_strike_pct']].head().apply(test, axis=1)
# Out:
# takdown_pct       0.25
# sig_strike_pct    0.52
# Name: 0, dtype: float64
# <class 'pandas.core.series.Series'>
#
# takdown_pct       0.25
# sig_strike_pct    0.52
# Name: 0, dtype: float64
# <class 'pandas.core.series.Series'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-a8acb4dfc477> in <module>
# ----> 1 stacked_data[['takdown_pct','sig_strike_pct']].head().apply(test, axis=1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# ...

# %%
## NOW go ahead and change some of the above datatypes to float values then we will go in and implement the 
#rolling mean on the columns we change dtype for. Then will add in more features by broadening the DF with
#column values that can be separated
stacked_data = stacked_data.astype({'knock_down': 'float64', 'sig_strike_pct':'float64'})

# %%
np.dtype(stacked_data['knock_down'])
# Out:
# dtype('float64')

# %%
#shifting data
shift_df = stacked_data[['fighter_name','knock_down','sig_strike_pct','takdown_pct','submission_att','pass','rev']]\
    .groupby(['fighter_name'])\
    .shift(periods = 1, axis = 0)

# %%
df4= pd.concat([stacked_data,shift_df], axis = 1)

# %%
df4.head()
# Out:
#            fighter_name  knock_down sig_strikes  sig_strike_pct total_strikes  \
# 0          Henry Cejudo         0.0   90 of 171            0.52     99 of 182
# 1  Valentina Shevchenko         1.0     8 of 11            0.72      37 of 40
# 2         Tony Ferguson         0.0  104 of 200            0.52    104 of 200
# 3         Jimmie Rivera         0.0   73 of 192            0.38     76 of 195
# 4           Tai Tuivasa         0.0   64 of 144            0.44     66 of 146
#
#   takedown  takdown_pct  submission_att  pass  rev       head      body  \
# 0   1 of 4         0.25               1     1    0  73 of 150  13 of 16
# 1   2 of 2         1.00               1     3    0     4 of 5    4 of 6
# 2   0 of 0         0.00               0     0    0  65 of 144  25 of 37
# 3   0 of 3         0.00               0     0    0  42 of 145  15 of 24
# 4   0 of 0         0.00               0     0    0  39 of 114    6 of 7
#
# ...

# %%
list(df4.columns)
# Out:
# ['fighter_name',
#  'knock_down',
#  'sig_strikes',
#  'sig_strike_pct',
#  'total_strikes',
#  'takedown',
#  'takdown_pct',
#  'submission_att',
#  'pass',
#  'rev',
#  'head',
#  'body',
#  'leg',
#  'distance',
#  'clinch',
#  'ground',
#  'height',
#  'weight',
#  'reach',
#  'stance',
#  'DOB',
#  'date',
#  'knock_down',
#  'sig_strike_pct',
#  'takdown_pct',
#  'submission_att',
#  'pass',
#  'rev']

# %%
#rename the columns
df4.columns=['fighter_name',
 'knock_down1',
 'sig_strikes',
 'sig_strike_pct1',
 'total_strikes',
 'takedown',
 'takdown_pct1',
 'submission_att1',
 'pass1',
 'rev1',
 'head',
 'body',
 'leg',
 'distance',
 'clinch',
 'ground',
 'height',
 'weight',
 'reach',
 'stance',
 'DOB',
 'date',
 'knock_down',
 'sig_strike_pct',
 'takdown_pct',
 'submission_att',
 'pass',
 'rev']

# %%
#drop the initial columns
cols = [1,3,6,7,8,9]
df4.drop(df4.columns[cols], axis=1, inplace = True)

# %%
#verify the drop occurred
df4.head()
# Out:
#            fighter_name sig_strikes total_strikes takedown       head  \
# 0          Henry Cejudo   90 of 171     99 of 182   1 of 4  73 of 150
# 1  Valentina Shevchenko     8 of 11      37 of 40   2 of 2     4 of 5
# 2         Tony Ferguson  104 of 200    104 of 200   0 of 0  65 of 144
# 3         Jimmie Rivera   73 of 192     76 of 195   0 of 3  42 of 145
# 4           Tai Tuivasa   64 of 144     66 of 146   0 of 0  39 of 114
#
#        body       leg    distance    clinch    ground  height    weight reach  \
# 0  13 of 16    4 of 5   45 of 118  19 of 23  26 of 30   5' 4"  135 lbs.   64"
# 1    4 of 6    0 of 0      5 of 8    2 of 2    1 of 1   5' 5"  125 lbs.   66"
# 2  25 of 37  14 of 19  103 of 198    1 of 2    0 of 0  5' 11"  155 lbs.   76"
# 3  15 of 24  16 of 23   60 of 173   9 of 15    4 of 4   5' 4"  135 lbs.   68"
# 4    6 of 7  19 of 23   50 of 126  14 of 18    0 of 0   6' 2"  264 lbs.   75"
#
# ...

# %%
#Lets do the roll
df5 = df4\
    .groupby(['fighter_name','date'])\
    .apply(lambda x: x.rolling(window=2, center=False, on='date', closed='right')[['knock_down','sig_strike_pct','takdown_pct','submission_att','pass','rev']]\
    .mean())

# %%
list(df5.columns)
# Out:
# ['date',
#  'knock_down',
#  'sig_strike_pct',
#  'takdown_pct',
#  'submission_att',
#  'pass',
#  'rev']

# %%
df5
# Out:
#             date  knock_down  sig_strike_pct  takdown_pct  submission_att  \
# 0     2019-06-08         NaN             NaN          NaN             NaN
# 1     2019-06-08         NaN             NaN          NaN             NaN
# 2     2019-06-08         NaN             NaN          NaN             NaN
# 3     2019-06-08         NaN             NaN          NaN             NaN
# 4     2019-06-08         NaN             NaN          NaN             NaN
# 5     2019-06-08         NaN             NaN          NaN             NaN
# 6     2019-06-08         NaN             NaN          NaN             NaN
# 7     2019-06-08         NaN             NaN          NaN             NaN
# 8     2019-06-08         NaN             NaN          NaN             NaN
# 9     2019-06-08         NaN             NaN          NaN             NaN
# 10    2019-06-08         NaN             NaN          NaN             NaN
# 11    2019-06-08         NaN             NaN          NaN             NaN
# ...

# %%
#Center should be false, play with documentation 'closed'
#df.groupby('id')['x'].rolling(2).mean()
#df.groupby(['col1', 'col2'])['col3'].apply(lambda x: x.rolling(window=3, center=True).mean())
g2 = stacked_data.groupby(['fighter_name']).apply(lambda x: x.rolling(window=3, center=True).mean())

# %%
print(g2)
